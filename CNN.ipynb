# %%
Importing Libraries
# Out:
#   File "<ipython-input-1-952af682003d>", line 1
#     Importing Libraries
#                       ^
# SyntaxError: invalid syntax

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %%
tf.__version__
# Out:
# '2.3.0'

# %%
Part 1 Datapreprocessing

# %% [markdown]
# preprocessing train set

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)
training_set = train_datagen.flow_from_directory(
        'C:\\Users\\s.boreda.varma\\OneDrive - Accenture\\Machine_Learning\\Deep_Learning_Dataset\\Section+40+-+Convolutional+Neural+Networks+(CNN)\\Section 40 - Convolutional Neural Networks (CNN)\\dataset\\training_set',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-418dfb311272> in <module>()
#       8         target_size=(64, 64),
#       9         batch_size=32,
# ---> 10         class_mode='binary')
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation)
#     957         follow_links=follow_links,
#     958         subset=subset,
# --> 959         interpolation=interpolation)
#     960
#     961   def flow_from_dataframe(self,
#
# ...

# %% [markdown]
# preprocessing test set

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory(
        'C:\\Users\\s.boreda.varma\\OneDrive - Accenture\\Machine_Learning\\Deep_Learning_Dataset\\Section+40+-+Convolutional+Neural+Networks+(CNN)\\Section 40 - Convolutional Neural Networks (CNN)\\dataset\\test_set',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')

# %% [markdown]
# Part 2 Building the CNN

# %% [markdown]
# Initialising the CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# Step 1 Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu',input_shape=[64, 64, 3]))

# %% [markdown]
# Step 2 Pooling (Addling pooling to Con layer)

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# Adding second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# Step 3 Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# Step 4 Full connection

# %%
cnn.add(tf.keras.layers.Dense(units=128,activation='relu'))

# %% [markdown]
# Step 5 Output layer

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# Part 3 - Training the CNN

# %% [markdown]
# compiling the CNN

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# training the CNN on training set and evaluating on test set

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)

# %% [markdown]
# Part 4 Make single prediction

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('C:\\Users\\s.boreda.varma\\OneDrive - Accenture\\Machine_Learning\\Deep_Learning_Dataset\\Section+40+-+Convolutional+Neural+Networks+(CNN)\\Section 40 - Convolutional Neural Networks (CNN)\\dataset\\single_prediction\\cat_or_dog_1.jpg',target_size=(64,64))
test_image = image.img_to_array('test_image')
test_image = np.expand_dims(test_image,axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'

# %%
print(prediction)
