# %% [markdown]
# Data preprocessing

# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.3.0'

# %% [markdown]
# Loading Dataset

# %%
dataset = pd.read_csv('Churn_Modelling.csv')
X = dataset.iloc[: , 3:-1].values
Y = dataset.iloc[: , -1].values

# %%
print(X)
# Out:
# [[619 'France' 'Female' ... 1 1 101348.88]
#  [608 'Spain' 'Female' ... 0 1 112542.58]
#  [502 'France' 'Female' ... 1 0 113931.57]
#  ...
#  [709 'France' 'Female' ... 0 1 42085.58]
#  [772 'Germany' 'Male' ... 1 0 92888.52]
#  [792 'France' 'Female' ... 1 0 38190.78]]

# %%
print(Y)
# Out:
# [1 0 1 ... 1 1 0]

# %%
dataset.isnull().sum(axis=0)
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# Encoding categorical data

# %% [markdown]
# Label encoding of Gender

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X[:, 2] = le.fit_transform(X[:,2])

# %%
print(X)
# Out:
# [[619 'France' 0 ... 1 1 101348.88]
#  [608 'Spain' 0 ... 0 1 112542.58]
#  [502 'France' 0 ... 1 0 113931.57]
#  ...
#  [709 'France' 0 ... 0 1 42085.58]
#  [772 'Germany' 1 ... 1 0 92888.52]
#  [792 'France' 0 ... 1 0 38190.78]]

# %% [markdown]
# One hot encoding to Geography

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(),[1])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %%
print(X)
# Out:
# [[1.0 0.0 0.0 ... 1 1 101348.88]
#  [0.0 0.0 1.0 ... 0 1 112542.58]
#  [1.0 0.0 0.0 ... 1 0 113931.57]
#  ...
#  [1.0 0.0 0.0 ... 0 1 42085.58]
#  [0.0 1.0 0.0 ... 1 0 92888.52]
#  [1.0 0.0 0.0 ... 1 0 38190.78]]

# %%
print(Y)
# Out:
# [1 0 1 ... 1 1 0]

# %% [markdown]
# Spllitting the train and test dataset

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=1234)

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
Y_test = sc.transform(X_test)

# %% [markdown]
# Building the ANN

# %% [markdown]
# Initialiation of ANN

# %%
ann = tf.keras.models.Sequential()

# %% [markdown]
# Adding input layer and first hidden layer

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %% [markdown]
# Adding second hidden layer

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %% [markdown]
# Adding the output layer

# %%
ann.add(tf.keras.layers.Dense(units=1, activation='relu'))

# %% [markdown]
# Part 3 Training the ANN

# %% [markdown]
# Compiling the ANN

# %%
ann.compile(optimizer= 'adam', loss= 'binary_crossentropy', metrics= ['accuracy'])

# %% [markdown]
# Training the ANN

# %%
ann.fit(X_train,Y_train, batch_size = 32, epochs=100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 0s 974us/step - loss: 0.5665 - accuracy: 0.7965
# Epoch 2/100
# 250/250 [==============================] - 0s 952us/step - loss: 0.4928 - accuracy: 0.7961
# Epoch 3/100
# 250/250 [==============================] - 0s 926us/step - loss: 0.4707 - accuracy: 0.8001
# Epoch 4/100
# 250/250 [==============================] - 0s 931us/step - loss: 0.4515 - accuracy: 0.8066
# Epoch 5/100
# 250/250 [==============================] - 0s 967us/step - loss: 0.4378 - accuracy: 0.8091
# Epoch 6/100
# 250/250 [==============================] - 0s 944us/step - loss: 0.4306 - accuracy: 0.8117
# Epoch 7/100
# 250/250 [==============================] - 0s 929us/step - loss: 0.4290 - accuracy: 0.8111
# Epoch 8/100
# 250/250 [==============================] - 0s 961us/step - loss: 0.4247 - accuracy: 0.8139
# 250/250 [==============================] - 0s 928us/step - loss: 0.3373 - accuracy: 0.8618
# Epoch 100/100
# 250/250 [==============================] - 0s 900us/step - loss: 0.3357 - accuracy: 0.8608

# %% [markdown]
# Part 4 Predictions of some customer in the dataset

# %%
print(ann.predict(sc.transform([[1, 0, 0, 600, 1, 40, 3, 60000, 2, 1, 1, 50000]])))
# Out:
# [[0.03319795]]

# %%
print(ann.predict(sc.transform([[1, 0, 0, 600, 1, 40, 3, 60000, 2, 1, 1, 50000]])) > 0.5)
# Out:
# [[False]]

# %% [markdown]
# Predicting test set results

# %%
import numpy as np

Y_pred = np.asarray(Y_pred).astype(np.float32)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-25239cc06eab> in <module>()
#       1 import numpy as np
#       2
# ----> 3 Y_pred = np.asarray(Y_pred).astype(np.float32)
#
# NameError: name 'Y_pred' is not defined

# %%
y_pred = ann.predict(X_test)
y_pred = (y_pred > 0.5)
print(np.concatenate((y_pred.reshape(len(y_pred),1),y_test.reshape(len(y_test),1)),1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-cc44d82066a6> in <module>()
# ----> 1 y_pred = ann.predict(X_test)
#       2 y_pred = (y_pred > 0.5)
#       3 print(np.concatenate((y_pred.reshape(len(y_pred),1),y_test.reshape(len(y_test),1)),1))
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     128       raise ValueError('{} is not supported in multi-worker mode.'.format(
#     129           method.__name__))
# --> 130     return method(self, *args, **kwargs)
#     131
#     132   return tf_decorator.make_decorator(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1577           use_multiprocessing=use_multiprocessing,
#    1578           model=self,
# -> 1579           steps_per_execution=self._steps_per_execution)
#    1580
#    1581       # Container that configures and calls `tf.keras.Callback`s.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution)
#    1115         use_multiprocessing=use_multiprocessing,
#    1116         distribution_strategy=ds_context.get_strategy(),
# -> 1117         model=model)
#    1118
#    1119     strategy = ds_context.get_strategy()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     263                **kwargs):
#     264     super(TensorLikeDataAdapter, self).__init__(x, y, **kwargs)
# --> 265     x, y, sample_weights = _process_tensorlike((x, y, sample_weights))
#     266     sample_weight_modes = broadcast_sample_weight_modes(
#     267         sample_weights, sample_weight_modes)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/data_adapter.py in _process_tensorlike(inputs)
#    1019     return x
#    1020
# -> 1021   inputs = nest.map_structure(_convert_numpy_and_scipy, inputs)
#    1022   return nest.list_to_tuple(inputs)
#    1023
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/data_adapter.py in _convert_numpy_and_scipy(x)
#    1014       if issubclass(x.dtype.type, np.floating):
#    1015         dtype = backend.floatx()
# -> 1016       return ops.convert_to_tensor(x, dtype=dtype)
#    1017     elif scipy_sparse and scipy_sparse.issparse(x):
#    1018       return _scipy_sparse_to_sparse_tensor(x)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1497
#    1498     if ret is None:
# -> 1499       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1500
#    1501     if ret is NotImplemented:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     262   """
#     263   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 264                         allow_broadcast=True)
#     265
#     266
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     273       with trace.Trace("tf.constant"):
#     274         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 275     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     276
#     277   g = ops.get_default_graph()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     298 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     299   """Implementation of eager constant."""
# --> 300   t = convert_to_eager_tensor(value, ctx, dtype)
#     301   if shape is None:
#     302     return t
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97   ctx.ensure_initialized()
# ---> 98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#     100
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type float).

# %% [markdown]
#  Making confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(Y_test,Y_pred)
print(cm)
accuracy_score(Y_test, Y_pred)

##Out was 
#[[1520  75]]
#[[202 203]]

##Acc 0.8615
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-cc01501a825e> in <module>()
#       1 from sklearn.metrics import confusion_matrix, accuracy_score
# ----> 2 cm = confusion_matrix(Y_test,Y_pred)
#       3 print(cm)
#       4 accuracy_score(Y_test, Y_pred)
#       5
#
# NameError: name 'Y_pred' is not defined
